# %%
from sklearn.datasets import make_regression

# %%
import matplotlib.pyplot as  plt
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
data = make_regression(n_samples=20, n_features=2, n_targets=1)
data
# Out:
# (array([[ 1.29741684,  0.96551308],
#         [-0.24378305,  0.70477758],
#         [-0.73128314, -1.93401139],
#         [-0.83824438, -0.30731901],
#         [-0.87953462, -1.15681752],
#         [ 1.96465897, -0.26877436],
#         [ 1.10080032, -0.6887142 ],
#         [-0.65031061, -0.1024114 ],
#         [-0.76778532, -1.97345862],
#         [-0.59599556,  0.90185958],
#         [ 0.79677633,  0.04470605],
#         [-1.0840287 , -0.79314199],
#         [-0.01335272, -0.42695804],
#         [ 0.19206303,  1.79921953],
#         [ 0.13453637,  2.10289902],
#         [-1.17370931,  0.60955431],
#         [-0.97105309,  1.30444206],
#         [ 0.00985856, -0.59923816],
#         [-0.76392857,  0.94506155],
#         [-0.57007576,  1.30671159]]),
#  array([ 114.09322437,    9.02566738, -112.08366919,  -62.83471033,
#          -94.61157718,  113.27090079,   44.96753826,  -44.07187773,
#         -115.71586244,   -6.16240601,   51.22137536,  -94.86160037,
#          -15.50962973,   73.82595847,   80.6779737 ,  -52.23510243,
#          -15.71079697,  -19.98450004,  -15.14910313,    9.37095871]))

# %%
X = data[0]
y = data[1]

# %%
plt.scatter(X[:,0], y, color="red")
plt.scatter(X[:,1], y, color="green")
plt.show()

# %%
df = pd.DataFrame(X, columns=["Col1", "Col2"])
df["target"] = y
df.head()
# Out:
#        Col1      Col2      target
# 0  1.297417  0.965513  114.093224
# 1 -0.243783  0.704778    9.025667
# 2 -0.731283 -1.934011 -112.083669
# 3 -0.838244 -0.307319  -62.834710
# 4 -0.879535 -1.156818  -94.611577

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor(max_depth=3)

# %%
dtr.fit(X, y)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
import sklearn.tree as tree

# %%
plt.figure(figsize=(20,16))
tree.plot_tree(dtr)
plt.show()
